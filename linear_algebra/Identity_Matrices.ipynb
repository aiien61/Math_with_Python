# %%
import numpy as np
import torch
import tensorflow as tf

# %%
I = torch.tensor([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
I
# Out:
# tensor([[1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1]])

# %%
x_pt = torch.tensor([25, 2, 5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
torch.matmul(I, x_pt)
# Out:
# tensor([25,  2,  5])
