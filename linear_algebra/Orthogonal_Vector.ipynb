# %% [markdown]
# *   **x** and **y** are orthogonal vectors if **x**$^T$**y**=0
# *   Orthogonal vectors are 90$^o$ angle to each others, assuming non-zero norms
# *   _n_-dimensional space has max _n_ mutually orthogonal vectors, assuming non-zero norms
# *   **Orthonormal** vectors are orthogonal and all ahve unit norm

# %%
import numpy as np

# %%
i = np.array([1, 0])
j = np.array([0, 1])

# %%
np.dot(i, j)
# Out:
# 0
