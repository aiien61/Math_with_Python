# %%
import numpy as np
import torch
import tensorflow as tf

# %%
X_sym = np.array([[0, 1, 2], [1, 1, 3], [2, 3, 2]])
X_sym
# Out:
# array([[0, 1, 2],
#        [1, 1, 3],
#        [2, 3, 2]])

# %%
X_sym.T
# Out:
# array([[0, 1, 2],
#        [1, 1, 3],
#        [2, 3, 2]])

# %%
np.all(X_sym.T == X_sym)
# Out:
# True
